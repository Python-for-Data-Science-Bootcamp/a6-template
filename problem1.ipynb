# %% [markdown]
# Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel$\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\rightarrow$Run All).
#
# Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE", as well as your name and collaborators below:

# %%
NAME = ""
COLLABORATORS = ""

# %% [markdown]
# ---

# %% [markdown]
# # Python for Data Science Bootcamp
# ## Assignment 6
#
# NOTE: This assignment has 4 problems.  Please write your code in the designated portion of the autograded answer cell.
#
# For this problem set, we'll be using the Jupyter notebook and nbgrader:
#
# ![](jupyter.png)
#
# ©2020 Luis Morales. All rights reserved.

# %% [markdown]
# ## Problem 1 (1 point)
#
# Create a function that estimates the area under the graph y = 1 /(x+1) using the Montecarlo procedure.

# %%
import pandas as pd
import numpy as np
def myfunction():
    
    # YOUR CODE HERE
    raise NotImplementedError()

# %% [markdown]
# ## Problem 2 (1 point)
#
# A doctor gives a patient a test for a particular cancer. Before the results of the test, the only evidence the doctor has to go on is that 1 woman in 100 has this cancer (P(cancer)=0.01, P(not cancer) = 0.99). Experience has shown that, in 99 percent of the cases in which cancer is present, the test is positive (P(+/cancer)=.99, P(-/cancer)=0.01); and in 95 percent of the cases in which it is not present, it is negative (P(-/not cancer)=0.95, P(-/not cancer)=0.95).
#
# If the test turns out to be positive, what probability should the doctor assign to the event that cancer is present? (i.e. P(cancer/+)=?)
#
# Show me how you calculate the final result. Hint: Draw tree diagram (forward and reverse) and calculate intersection probabilities.
# ![image.png](attachment:image.png)

# %%
def myfunction():
    # YOUR CODE HERE
    # YOUR CODE HERE
    raise NotImplementedError()

# %%
assert abs(myfunction()-1/6)<0.0001

# %% [markdown]
# ## Problem 3 (1 point)
#
# Feller discusses the statistics of flying bomb hits in an area in the south of London during the Second World War. The area in question was divided into 24 × 24 = 576 small areas. The total number of hits was 537. Assuming the hits were purely random, use the Poisson approximation to find the probability that a particular square would have exactly k hits. Write a function to compute the probability that one arbitraty area would have k hits. Hint: n=537 (successful hits), p = 1/576 (all squares equally likely), lambda = ?
# ![image.png](attachment:image.png)

# %%
from math import factorial
import numpy as np
def myfunction(k):
    # YOUR CODE HERE
    # YOUR CODE HERE
    raise NotImplementedError()

# %%
assert abs(myfunction(0)-0.39365)<0.01
assert abs(myfunction(1)-0.366997)<0.01
assert abs(myfunction(2)-0.1710)<0.01
assert abs(myfunction(3)-0.05316)<0.01

# %% [markdown]
# ## Problem 4 (1 point)
#
# Through simulation, calculate probability that after rolling a dice twice, the smaller value will be a 2. Hint: np.min

# %%
import numpy as np
def myfunction2():
    '''simulation answer, please write codes to simulate the random experiments and calculate the answer'''
    # YOUR CODE HERE
    raise NotImplementedError()

# %%
assert abs(myfunction2()-0.25)<0.01
